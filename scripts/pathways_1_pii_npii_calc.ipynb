# %% [markdown]
# # Pathways workflow
# ## Calculating PII and NPII values

# %%
import os
import os.path
import glob
import pathlib

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from collections import defaultdict
from xlrd import open_workbook

# %%
#my_tag = "H3K4me3"
#my_tag = "H3K27me3"
my_tags = ["H3K4me3", "H3K9ac", "H3K27ac", "H3K27me3", "H3K9me3"]

# %%
pathway_tables = glob.glob("../pathways/*/gp.csv")

# %%
pathway_tables
# Out:
# ['../pathways/Metabolism 1.1/gp.csv',
#  '../pathways/Biocarta 1.0.1/gp.csv',
#  '../pathways/KEGG Adjusted 1.2/gp.csv',
#  '../pathways/Cytoskeleton 1.0/gp.csv',
#  '../pathways/Reactome 1.1.1/gp.csv',
#  '../pathways/Primary 1.2/gp.csv',
#  '../pathways/NCI 1.0/gp.csv']

# %%
dfs = [pd.read_csv(table) for table in pathway_tables]
for i, df in enumerate(dfs):
    dfs[i] = df.set_index("SYMBOL")
    dfs[i].sort_index(inplace=True)
    #print(dfs[i].shape)
dfs[0]
united_df = pd.concat(dfs, axis=1, sort=True)  # sorting added
united_df.shape
len(set(united_df.index))
# Out:
# 9134

# %%
## REPLACING NA WITH ZEROS (0)
united_df.fillna(value=0, inplace=True)
print(united_df.shape)
united_df.head()
# Out:
# (9134, 3126)
#         125-dihydroxyvitamin_Dsub3sub_biosynthesis  \
# A2M                                            0.0
# A4GALT                                         0.0
# A4GNT                                          0.0
# AAAS                                           0.0
# AACS                                           0.0
#
#         1D-imyoi-inositol_hexakisphosphate_biosynthesis_II_mammalian  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         1D-imyoi-inositol_hexakisphosphate_biosynthesis_V_from_Ins134P3  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         2-amino-3-carboxymuconate_semialdehyde_degradation_to_glutaryl-CoA  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         2-deoxy-alpha-D-ribose_1-phosphate_degradation  \
# A2M                                                0.0
# A4GALT                                             0.0
# A4GNT                                              0.0
# AAAS                                               0.0
# AACS                                               0.0
#
#         2-oxobutanoate_degradation  \
# A2M                            0.0
# A4GALT                         0.0
# A4GNT                          0.0
# AAAS                           0.0
# AACS                           0.0
#
#         2-oxoglutarate_decarboxylation_to_succinyl-CoA  \
# A2M                                                0.0
# A4GALT                                             0.0
# A4GNT                                              0.0
# AAAS                                               0.0
# AACS                                               0.0
#
#         2-oxoisovalerate_decarboxylation_to_isobutanoyl-CoA  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         3-phosphoinositide_biosynthesis  3-phosphoinositide_degradation  \
# A2M                                 0.0                             0.0
# A4GALT                              0.0                             0.0
# A4GNT                               0.0                             0.0
# AAAS                                0.0                             0.0
# AACS                                0.0                             0.0
#
#                                           ...                                     \
# A2M                                       ...
# A4GALT                                    ...
# A4GNT                                     ...
# AAAS                                      ...
# AACS                                      ...
#
#         NCI_p53_Main_Pathway  NCI_p53_Pathway_(apoptosis)  \
# A2M                      0.0                          0.0
# A4GALT                   0.0                          0.0
# A4GNT                    0.0                          0.0
# AAAS                     0.0                          0.0
# AACS                     0.0                          0.0
#
#         NCI_p53_Pathway_(proteasomal_ubiquitin_dependent_protein_catabolic_process)  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         NCI_p73_transcription_factor_network_Main_Pathway  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         NCI_p73_transcription_factor_network_Pathway_(apoptosis)  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         NCI_p75_NTR_mediated_signaling_Main_Pathway  \
# A2M                                             0.0
# A4GALT                                          0.0
# A4GNT                                           0.0
# AAAS                                            0.0
# AACS                                            0.0
#
#         NCI_p75_NTR_mediated_signaling_Pathway_(activation_of_caspase_activity)  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         NCI_p75_NTR_mediated_signaling_Pathway_(cell_cycle_arrest)  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         NCI_p75_NTR_mediated_signaling_Pathway_(neuron_apoptosis)  \
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
#         NCI_p75_NTR_mediated_signaling_Pathway_(neuron_projection_morphogenesis)
# A2M                                                   0.0
# A4GALT                                                0.0
# A4GNT                                                 0.0
# AAAS                                                  0.0
# AACS                                                  0.0
#
# [5 rows x 3126 columns]

# %%
genes = list(united_df.index)

# %%
all_pathways = list(united_df.columns)

# %%
tables_human = dict()
tables_mouse = dict()
for hg_tag in my_tags:
    gre_human_tables = glob.glob("../human/gre/GRE*.xlsx")
    #gre_human_tables = [f"file://localhost{os.path.abspath(path)}" for path in glob.glob("./data/human/GRE*.xlsx")]
    gre_mouse_tables = glob.glob(f"../mouse/gre/*_GRE*{hg_tag}.txt")

    gre_human_dfs = [pd.read_excel(open_workbook(table), sheet_name=hg_tag, index_col="Gene_name", engine="xlrd") for table in gre_human_tables]

    gre_mouse_dfs = [pd.read_csv(table, index_col="gene", sep="\t") for table in gre_mouse_tables]

    # pair (GRE, GTE)
    tables_human[hg_tag] = [(df["gene_signal"], df["total_signal"]) for df in gre_human_dfs]
    tables_mouse[hg_tag] = [(df["gene_signal"], df["total_signal"]) for df in gre_mouse_dfs]

# %% [markdown]
# ## HUMAN

# %%
FDATA_HUMAN = defaultdict(dict)
for i, hg_tag in enumerate(my_tags):
    total_gre_human = None
    total_gte_human = None
    for pair in tables_human[hg_tag]:
        total_gre_human = pair[1] if total_gre_human is None else total_gre_human + pair[1]
        total_gte_human = pair[0] if total_gte_human is None else total_gte_human + pair[0]

    GENES_HUMAN = sorted(set(genes) & set(total_gre_human.index) & set(total_gte_human.index))
    #print(len(genes), len(GENES_HUMAN))
    missing_genes = sorted(set(genes) - (set(genes) & set(total_gre_human.index) & set(total_gte_human.index)))
    #print(len(missing_genes) + len(GENES_HUMAN))

    #print("non-cut\t", len(total_gre_human), len(total_gte_human))
    total_gre_human = total_gre_human.reindex(GENES_HUMAN, copy=False)
    total_gte_human = total_gte_human.reindex(GENES_HUMAN, copy=False)
    #print("cut\t", len(total_gre_human), len(total_gte_human))

    united_df_human = united_df.reindex(GENES_HUMAN)
    print("matrix shape:", united_df_human.shape)

    PII_HUMAN = pd.Series()
    NPII_HUMAN = pd.Series()
    for column_id in united_df_human:
        column = united_df_human[column_id]
        n = column.fillna(0).sum()
        gre_score_n = sum(column.multiply(total_gre_human))
        gte_score_n = sum(column.multiply(total_gte_human))
        pii_score = gre_score_n / n
        try:
            npii_score = gre_score_n / gte_score_n
        except ZeroDivisionError:
            npii_score = 0.0
        PII_HUMAN = PII_HUMAN.append(pd.Series({column_id: pii_score}), verify_integrity=True)
        NPII_HUMAN = NPII_HUMAN.append(pd.Series({column_id: npii_score}), verify_integrity=True)
    FDATA_HUMAN["PII"][hg_tag] = PII_HUMAN
    FDATA_HUMAN["NPII"][hg_tag] = NPII_HUMAN
# Out:
# matrix shape: (8676, 3126)
# /home/arsen_l/.local/lib/python3.6/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
# matrix shape: (8676, 3126)
# matrix shape: (8676, 3126)
# matrix shape: (8676, 3126)
# matrix shape: (8676, 3126)

# %% [markdown]
# ## MOUSE

# %%
FDATA_MOUSE = defaultdict(dict)
for i, hg_tag in enumerate(my_tags):
    total_gre_mouse = None
    total_gte_mouse = None
    for pair in tables_mouse[hg_tag]:
        total_gre_mouse = pair[1] if total_gre_mouse is None else total_gre_mouse + pair[1]
        total_gte_mouse = pair[0] if total_gte_mouse is None else total_gte_mouse + pair[0]

    GENES_MOUSE = sorted(set(genes) & set(total_gre_mouse.index) & set(total_gte_mouse.index))
    #print(len(genes), len(GENES_MOUSE))
    missing_genes = sorted(set(genes) - (set(genes) & set(total_gre_mouse.index) & set(total_gte_mouse.index)))
    #print(len(missing_genes) + len(GENES_MOUSE))

    #print("non-cut\t", len(total_gre_mouse), len(total_gte_mouse))
    total_gre_mouse = total_gre_mouse.reindex(GENES_MOUSE, copy=False)
    total_gte_mouse = total_gte_mouse.reindex(GENES_MOUSE, copy=False)
    #print("cut\t", len(total_gre_mouse), len(total_gte_mouse))

    united_df_mouse = united_df.reindex(GENES_MOUSE)
    print("matrix shape:", united_df_mouse.shape)

    PII_MOUSE = pd.Series()
    NPII_MOUSE = pd.Series()
    for column_id in united_df_mouse:
        column = united_df_mouse[column_id]
        n = column.fillna(0).sum()
        gre_score_n = sum(column.multiply(total_gre_mouse))
        gte_score_n = sum(column.multiply(total_gte_mouse))
        pii_score = gre_score_n / n
        try:
            npii_score = gre_score_n / gte_score_n
        except ZeroDivisionError:
            npii_score = 0.0
        PII_MOUSE = PII_MOUSE.append(pd.Series({column_id: pii_score}), verify_integrity=True)
        NPII_MOUSE = NPII_MOUSE.append(pd.Series({column_id: npii_score}), verify_integrity=True)
    FDATA_MOUSE["PII"][hg_tag] = PII_MOUSE
    FDATA_MOUSE["NPII"][hg_tag] = NPII_MOUSE
# Out:
# matrix shape: (8121, 3126)
# /home/arsen_l/.local/lib/python3.6/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
# matrix shape: (8121, 3126)
# matrix shape: (8121, 3126)
# matrix shape: (8121, 3126)
# matrix shape: (8121, 3126)

# %%
OUT_DICT = dict()
for i, hg_tag in enumerate(my_tags):
    OUT_DICT[f"PII_HUMAN_{hg_tag}"] = FDATA_HUMAN["PII"][hg_tag]
    OUT_DICT[f"NPII_HUMAN_{hg_tag}"] = FDATA_HUMAN["NPII"][hg_tag]
    OUT_DICT[f"PII_MOUSE_{hg_tag}"] = FDATA_MOUSE["PII"][hg_tag]
    OUT_DICT[f"NPII_MOUSE_{hg_tag}"] = FDATA_MOUSE["NPII"][hg_tag]

# %%
OUT_DF = pd.DataFrame(OUT_DICT)

# %%
OUT_DF.head()
# Out:
#                                                     PII_HUMAN_H3K4me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                   2.248360
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           5.605292
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           1.042087
# 2-amino-3-carboxymuconate_semialdehyde_degradat...           6.896377
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation               8.357360
#
#                                                     NPII_HUMAN_H3K4me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                    0.375890
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            0.799023
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            1.500849
# 2-amino-3-carboxymuconate_semialdehyde_degradat...            1.313218
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                1.102882
#
#                                                     PII_MOUSE_H3K4me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                  18.982333
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...          36.733933
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...          82.579000
# 2-amino-3-carboxymuconate_semialdehyde_degradat...          38.378500
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation              24.065600
#
#                                                     NPII_MOUSE_H3K4me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                    1.600691
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            8.579047
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           13.647767
# 2-amino-3-carboxymuconate_semialdehyde_degradat...           30.351932
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                2.444360
#
#                                                     PII_HUMAN_H3K9ac  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                  2.391201
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...          6.174049
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...          1.810458
# 2-amino-3-carboxymuconate_semialdehyde_degradat...          8.087387
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation              8.118468
#
#                                                     NPII_HUMAN_H3K9ac  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                   0.636846
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           0.861989
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           1.605907
# 2-amino-3-carboxymuconate_semialdehyde_degradat...           1.375695
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation               1.206915
#
#                                                     PII_MOUSE_H3K9ac  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                 15.014000
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...         32.454067
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...         65.185000
# 2-amino-3-carboxymuconate_semialdehyde_degradat...         26.035000
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation             23.023800
#
#                                                     NPII_MOUSE_H3K9ac  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                   1.060750
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           5.485992
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           7.035922
# 2-amino-3-carboxymuconate_semialdehyde_degradat...          22.939337
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation               1.328723
#
#                                                     PII_HUMAN_H3K27ac  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                   2.607717
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           7.398026
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           2.612022
# 2-amino-3-carboxymuconate_semialdehyde_degradat...           9.118160
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation              11.054988
#
#                                                     NPII_HUMAN_H3K27ac  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                    0.730111
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            1.086097
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            0.984017
# 2-amino-3-carboxymuconate_semialdehyde_degradat...            2.102414
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                1.552252
#
#                                                     PII_MOUSE_H3K27ac  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                  10.488333
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...          23.632267
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...          33.130333
# 2-amino-3-carboxymuconate_semialdehyde_degradat...          14.899500
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation              12.941200
#
#                                                     NPII_MOUSE_H3K27ac  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                    1.162761
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            5.620164
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            4.765789
# 2-amino-3-carboxymuconate_semialdehyde_degradat...           13.832335
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                0.826807
#
#                                                     PII_HUMAN_H3K27me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                    3.312624
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            3.561952
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            1.454336
# 2-amino-3-carboxymuconate_semialdehyde_degradat...            7.612660
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                6.275483
#
#                                                     NPII_HUMAN_H3K27me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                     0.717225
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...             0.831201
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...             0.503590
# 2-amino-3-carboxymuconate_semialdehyde_degradat...             1.958742
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                 1.351197
#
#                                                     PII_MOUSE_H3K27me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                   16.368333
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           20.007467
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           24.618000
# 2-amino-3-carboxymuconate_semialdehyde_degradat...           28.476000
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation               13.614600
#
#                                                     NPII_MOUSE_H3K27me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                    13.641415
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            12.638530
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            21.278668
# 2-amino-3-carboxymuconate_semialdehyde_degradat...            20.090306
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                 9.236750
#
#                                                     PII_HUMAN_H3K9me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                   3.757602
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           3.625598
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           2.147989
# 2-amino-3-carboxymuconate_semialdehyde_degradat...           8.971827
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation               5.201340
#
#                                                     NPII_HUMAN_H3K9me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                    0.881069
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            0.869489
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...            0.558334
# 2-amino-3-carboxymuconate_semialdehyde_degradat...            1.586740
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                1.194269
#
#                                                     PII_MOUSE_H3K9me3  \
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                  11.621333
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...          15.303000
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...          19.076000
# 2-amino-3-carboxymuconate_semialdehyde_degradat...          21.058000
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation               9.229000
#
#                                                     NPII_MOUSE_H3K9me3
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                    8.959243
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           11.036719
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...           15.254292
# 2-amino-3-carboxymuconate_semialdehyde_degradat...            8.468932
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                8.535097

# %%
OUT_DF.dropna().shape
OUT_DF.dropna().to_csv(f"../extracted/pii-vs-npii.all.csv")
