# %% [markdown]
# # Analysis of enrichment

# %%
import glob

import json
import math

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from functools import reduce
from collections import OrderedDict, defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.stats import fisher_exact as fisher
from scipy.stats import chi2_contingency as chisq

# %%
def ease(n_outliers_path, n_total_path, n_outliers, n_total):
    """
    Calculates a contingency table EASE score
    [x y]
    [z k]
    :param n_in_path: number of outliers in the pathway
    :param n_total_path: total number of genes in the pathway
    :param n_outliers: total number of outliers
    :param n_total: total number of genes analysed
    :return:
    """

    x = max(0, n_outliers_path - 1)   # in category, enriched
    y = n_total_path                  # total,       enriched
    z = n_outliers - n_outliers_path  # in category, not enriched
    k = n_total - n_total_path        # total,       not enriched
    
    #if x <= 10:
    _, pvalue = fisher(([[x, y], [z, k]]), alternative='greater')
    #else:
    #    _, pvalue, _, _ = chisq(([[x, y], [z, k]]))

    return pvalue

# %% [markdown]
# ## Collecting all pathway names

# %%
pathway_tables = glob.glob("../pathways/*/gp.csv")
dfs = [pd.read_csv(table) for table in pathway_tables]
for i, df in enumerate(dfs):
    dfs[i] = df.set_index("SYMBOL")
    dfs[i].sort_index(inplace=True)
    #print(dfs[i].shape)
dfs[0]
all_entries = list(pd.concat(dfs, axis=1, sort=True).columns)

# %%
all_entries[0:10]
# Out:
# ['125-dihydroxyvitamin_Dsub3sub_biosynthesis',
#  '1D-imyoi-inositol_hexakisphosphate_biosynthesis_II_mammalian',
#  '1D-imyoi-inositol_hexakisphosphate_biosynthesis_V_from_Ins134P3',
#  '2-amino-3-carboxymuconate_semialdehyde_degradation_to_glutaryl-CoA',
#  '2-deoxy-alpha-D-ribose_1-phosphate_degradation',
#  '2-oxobutanoate_degradation',
#  '2-oxoglutarate_decarboxylation_to_succinyl-CoA',
#  '2-oxoisovalerate_decarboxylation_to_isobutanoyl-CoA',
#  '3-phosphoinositide_biosynthesis',
#  '3-phosphoinositide_degradation']

# %%
structures = pd.read_csv("../extracted/classification_pathways.csv", header=0, index_col="Pathway")
structures = pd.DataFrame(structures, dtype=bool)

# %%
del structures["DUPLICATE?"], structures["TRUTHFULNESS"], structures["Garbage"]
structures.head()
# Out:
#                                                     Carbohydrates Metabolism  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                             False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                     False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                     False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                     False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                         False
#
#                                                     Aminoacids and Polyamines Metabolism  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                          True
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                 False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                 False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                                 False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                     False
#
#                                                     Lipids Metabolism  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                      False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...              False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...              False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...              False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                  False
#
#                                                     Nucleic Base Metabolism  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                            False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                    False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                    False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                    False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                        False
#
#                                                     Catabolism of Xenobiotics  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                              False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                      False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                      False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                       True
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                          False
#
#                                                     Vitamin Metabolism  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                       False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...               False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...               False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...               False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                    True
#
#                                                     Translation and protein maturation  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                       False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                               False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                               False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                               False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                   False
#
#                                                     Signaling  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis              False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...      False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...      False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...      False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation          False
#
#                                                     Perception and Neurotransmission  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                     False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                              True
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                              True
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                             False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                 False
#
#                                                     Immunity Linked Pathways  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                             False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                     False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                     False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                     False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                         False
#
#                                                     ...    \
# Pathway                                             ...
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis          ...
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...  ...
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...  ...
# 2-amino-3-carboxymuconate_semialdehyde_degradat...  ...
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation      ...
#
#                                                     Cell cycle regulation and apoptosis  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                        False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                                False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                    False
#
#                                                     Molecular Transport pathways  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                 False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                         False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                         False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                         False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                             False
#
#                                                     Invasive Disease  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                     False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...             False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...             False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...             False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                 False
#
#                                                     Cytoskeleton Organisation and Cell Adhesion Linked Pathways   \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                                      False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                              False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                              False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                                              False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                                  False
#
#                                                     Cancer and Tumorigenesis Linked Pathways  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                             False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                     False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                     False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                                     False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                         False
#
#                                                     Chromatin Structure Linked Pathways  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                        False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                                False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                    False
#
#                                                     RNA synthesis, processing and degradation  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                              False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                      False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                      False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                                      False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                          False
#
#                                                     DNA replication, recombination and repair  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                              False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                      False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                                      False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                                      False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                                          False
#
#                                                     Mitochondria Linked Pathways  \
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis                                 False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                         False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...                         False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...                         False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation                             False
#
#                                                     Other
# Pathway
# 125-dihydroxyvitamin_Dsub3sub_biosynthesis          False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...  False
# 1D-imyoi-inositol_hexakisphosphate_biosynthesis...  False
# 2-amino-3-carboxymuconate_semialdehyde_degradat...  False
# 2-deoxy-alpha-D-ribose_1-phosphate_degradation      False
#
# [5 rows x 22 columns]

# %%
all_2 = set(structures.index)
set(all_entries) - all_2
# Out:
# set()

# %%
pathway_types = dict()
for pathway in sorted(all_entries):
    x = structures.loc[pathway]
    pathway_types[pathway] = x[x].index[0]

# %%
reverse_counter = defaultdict(int)
for pathway in sorted(all_entries):
    category = pathway_types[pathway]
    reverse_counter[category] += 1
reverse_counter
# Out:
# defaultdict(int,
#             {'Aminoacids and Polyamines Metabolism': 119,
#              'Perception and Neurotransmission': 83,
#              'Catabolism of Xenobiotics': 48,
#              'Vitamin Metabolism': 43,
#              'Lipids Metabolism': 147,
#              'Nucleic Base Metabolism': 78,
#              'Other': 104,
#              'Signaling': 1178,
#              'Cancer and Tumorigenesis Linked Pathways': 65,
#              'Cell cycle regulation and apoptosis': 277,
#              'DNA replication, recombination and repair': 104,
#              'Molecular Transport pathways': 105,
#              'Chromatin Structure Linked Pathways': 42,
#              'Hormone Linked Pathways': 91,
#              'Immunity Linked Pathways': 213,
#              'Carbohydrates Metabolism': 87,
#              'Cytoskeleton Organisation and Cell Adhesion Linked Pathways ': 122,
#              'Translation and protein maturation': 59,
#              'Invasive Disease': 37,
#              'Mitochondria Linked Pathways': 36,
#              'RNA synthesis, processing and degradation': 62,
#              'Sulfur Metabolism and Linked Redox Reactions': 26})

# %%
ALL_PATHS = sum(reverse_counter.values())
ALL_PATHS
# Out:
# 3126

# %% [markdown]
# # By histone tag:

# %%
my_tags = ["H3K4me3", "H3K9ac", "H3K27ac", "H3K27me3", "H3K9me3"]

# %%
ENR_COUNTERS = dict()
for hg_tag in my_tags:
    files_up_human = glob.glob(f"../extracted/Human_{hg_tag}_pathways_up*")
    files_down_human = glob.glob(f"../extracted/Human_{hg_tag}_pathways_down*")
    files_up_mouse = glob.glob(f"../extracted/Mouse_{hg_tag}_pathways_up*")
    files_down_mouse = glob.glob(f"../extracted/Mouse_{hg_tag}_pathways_down*")

    files = {"Human+": files_up_human[0],
             "Human-": files_down_human[0],
             "Mouse+": files_up_mouse[0],
             "Mouse-": files_down_mouse[0]}

    enriched_counter = defaultdict(lambda: defaultdict(int))
    for xtype in files:
        with open(files[xtype], "r") as file:
            en_pathways = file.read().strip().split("\n")
        for pw in en_pathways:
            cat = pathway_types[pw]
            enriched_counter[xtype][cat] += 1
    enriched_counter = pd.DataFrame(enriched_counter).T.fillna(0)
    enriched_counter = pd.DataFrame(enriched_counter, dtype=int)
    ENR_COUNTERS[hg_tag] = enriched_counter
ENR_COUNTERS[my_tags[0]]
# Out:
#         Aminoacids and Polyamines Metabolism  \
# Human+                                    16
# Human-                                     1
# Mouse+                                     3
# Mouse-                                     5
#
#         Cancer and Tumorigenesis Linked Pathways  Carbohydrates Metabolism  \
# Human+                                         1                         5
# Human-                                         0                         3
# Mouse+                                         1                         1
# Mouse-                                         0                         3
#
#         Catabolism of Xenobiotics  Cell cycle regulation and apoptosis  \
# Human+                          6                                    6
# Human-                          0                                    4
# Mouse+                          5                                    6
# Mouse-                          2                                   11
#
#         Chromatin Structure Linked Pathways  \
# Human+                                    0
# Human-                                    1
# Mouse+                                    0
# Mouse-                                    1
#
#         Cytoskeleton Organisation and Cell Adhesion Linked Pathways   \
# Human+                                                  2
# Human-                                                  1
# Mouse+                                                  1
# Mouse-                                                  8
#
#         DNA replication, recombination and repair  Hormone Linked Pathways  \
# Human+                                          0                        4
# Human-                                          4                        0
# Mouse+                                          1                        0
# Mouse-                                          6                        2
#
#         Immunity Linked Pathways         ...          \
# Human+                        12         ...
# Human-                         1         ...
# Mouse+                         2         ...
# Mouse-                         5         ...
#
#         Mitochondria Linked Pathways  Molecular Transport pathways  \
# Human+                             0                             8
# Human-                             0                             0
# Mouse+                             3                             0
# Mouse-                             1                            10
#
#         Nucleic Base Metabolism  Other  Perception and Neurotransmission  \
# Human+                        5      2                                10
# Human-                        5      8                                 0
# Mouse+                        2      1                                 1
# Mouse-                        5      4                                 0
#
#         RNA synthesis, processing and degradation  Signaling  \
# Human+                                          0          9
# Human-                                          5          5
# Mouse+                                          0          8
# Mouse-                                          4         31
#
#         Sulfur Metabolism and Linked Redox Reactions  \
# Human+                                             3
# Human-                                             0
# Mouse+                                             2
# Mouse-                                             1
#
#         Translation and protein maturation  Vitamin Metabolism
# Human+                                   0                   4
# Human-                                   7                   0
# Mouse+                                   1                   1
# Mouse-                                   5                   2
#
# [4 rows x 22 columns]

# %% [markdown]
# Calculates a contingency table EASE score
# [x y]
# [z k]
# :param n_in_path: number of outliers in the pathway
# :param n_total_path: total number of genes in the pathway
# :param n_outliers: total number of outliers
# :param n_total: total number of genes analysed
# :return:

# %%
ksi = defaultdict(dict)
signs = {"+": "positively\u00A0enriched\u00A0(+)",
        "-": "negatively\u00A0enriched\u00A0(-)"}
for hg_tag in my_tags:
    enriched_counter = ENR_COUNTERS[hg_tag]
    for sign in ["+", "-"]:
        for org in ["Human", "Mouse"]:
            for category in enriched_counter:
                n1 = enriched_counter[category][f"{org}{sign}"]
                n2 = sum(enriched_counter.loc[f"{org}{sign}"])
                n3 = reverse_counter[category]
                n4 = ALL_PATHS
                #print(n1, n2, n3, n4)
                ksi[category][f"{org},\u00A0{hg_tag},\u00A0{signs[sign]}"] = ease(n1, n2, n3, n4)
pd.DataFrame(ksi).to_csv(f"../extracted/pvalues.csv")
pd.DataFrame(ksi)
# Out:
#                                           Aminoacids and Polyamines Metabolism  \
# Human, H3K27ac, negatively enriched (-)                               1.000000
# Human, H3K27ac, positively enriched (+)                               0.000002
# Human, H3K27me3, negatively enriched (-)                              0.403831
# Human, H3K27me3, positively enriched (+)                              0.713530
# Human, H3K4me3, negatively enriched (-)                               1.000000
# Human, H3K4me3, positively enriched (+)                               0.000020
# Human, H3K9ac, negatively enriched (-)                                1.000000
# Human, H3K9ac, positively enriched (+)                                0.000002
# Human, H3K9me3, negatively enriched (-)                               0.905330
# Human, H3K9me3, positively enriched (+)                               0.154421
# Mouse, H3K27ac, negatively enriched (-)                               0.908113
# Mouse, H3K27ac, positively enriched (+)                               0.323372
# Mouse, H3K27me3, negatively enriched (-)                              0.000002
# Mouse, H3K27me3, positively enriched (+)                              0.033401
# Mouse, H3K4me3, negatively enriched (-)                               0.609471
# Mouse, H3K4me3, positively enriched (+)                               0.526758
# Mouse, H3K9ac, negatively enriched (-)                                0.921186
# Mouse, H3K9ac, positively enriched (+)                                0.537982
# Mouse, H3K9me3, negatively enriched (-)                               0.424020
# Mouse, H3K9me3, positively enriched (+)                               0.273670
#
#                                           Cancer and Tumorigenesis Linked Pathways  \
# Human, H3K27ac, negatively enriched (-)                                   1.000000
# Human, H3K27ac, positively enriched (+)                                   1.000000
# Human, H3K27me3, negatively enriched (-)                                  1.000000
# Human, H3K27me3, positively enriched (+)                                  1.000000
# Human, H3K4me3, negatively enriched (-)                                   1.000000
# Human, H3K4me3, positively enriched (+)                                   1.000000
# Human, H3K9ac, negatively enriched (-)                                    1.000000
# Human, H3K9ac, positively enriched (+)                                    1.000000
# Human, H3K9me3, negatively enriched (-)                                   1.000000
# Human, H3K9me3, positively enriched (+)                                   1.000000
# Mouse, H3K27ac, negatively enriched (-)                                   0.173547
# Mouse, H3K27ac, positively enriched (+)                                   1.000000
# Mouse, H3K27me3, negatively enriched (-)                                  0.864173
# Mouse, H3K27me3, positively enriched (+)                                  1.000000
# Mouse, H3K4me3, negatively enriched (-)                                   1.000000
# Mouse, H3K4me3, positively enriched (+)                                   1.000000
# Mouse, H3K9ac, negatively enriched (-)                                    1.000000
# Mouse, H3K9ac, positively enriched (+)                                    1.000000
# Mouse, H3K9me3, negatively enriched (-)                                   1.000000
# Mouse, H3K9me3, positively enriched (+)                                   1.000000
#
#                                           Carbohydrates Metabolism  \
# Human, H3K27ac, negatively enriched (-)                   1.000000
# Human, H3K27ac, positively enriched (+)                   0.296924
# Human, H3K27me3, negatively enriched (-)                  1.000000
# Human, H3K27me3, positively enriched (+)                  0.751213
# Human, H3K4me3, negatively enriched (-)                   0.417812
# Human, H3K4me3, positively enriched (+)                   0.333787
# Human, H3K9ac, negatively enriched (-)                    0.806742
# Human, H3K9ac, positively enriched (+)                    0.512439
# Human, H3K9me3, negatively enriched (-)                   1.000000
# Human, H3K9me3, positively enriched (+)                   0.735655
# Mouse, H3K27ac, negatively enriched (-)                   0.946364
# Mouse, H3K27ac, positively enriched (+)                   1.000000
# Mouse, H3K27me3, negatively enriched (-)                  0.930972
# Mouse, H3K27me3, positively enriched (+)                  0.507627
# Mouse, H3K4me3, negatively enriched (-)                   0.813894
# Mouse, H3K4me3, positively enriched (+)                   1.000000
# Mouse, H3K9ac, negatively enriched (-)                    0.809925
# Mouse, H3K9ac, positively enriched (+)                    0.730842
# Mouse, H3K9me3, negatively enriched (-)                   0.435708
# Mouse, H3K9me3, positively enriched (+)                   1.000000
#
#                                           Catabolism of Xenobiotics  \
# Human, H3K27ac, negatively enriched (-)                    1.000000
# Human, H3K27ac, positively enriched (+)                    0.017659
# Human, H3K27me3, negatively enriched (-)                   1.000000
# Human, H3K27me3, positively enriched (+)                   0.434494
# Human, H3K4me3, negatively enriched (-)                    1.000000
# Human, H3K4me3, positively enriched (+)                    0.022003
# Human, H3K9ac, negatively enriched (-)                     1.000000
# Human, H3K9ac, positively enriched (+)                     0.062502
# Human, H3K9me3, negatively enriched (-)                    1.000000
# Human, H3K9me3, positively enriched (+)                    1.000000
# Mouse, H3K27ac, negatively enriched (-)                    0.799881
# Mouse, H3K27ac, positively enriched (+)                    0.046730
# Mouse, H3K27me3, negatively enriched (-)                   0.770093
# Mouse, H3K27me3, positively enriched (+)                   0.000048
# Mouse, H3K4me3, negatively enriched (-)                    0.817604
# Mouse, H3K4me3, positively enriched (+)                    0.005913
# Mouse, H3K9ac, negatively enriched (-)                     0.814761
# Mouse, H3K9ac, positively enriched (+)                     0.514083
# Mouse, H3K9me3, negatively enriched (-)                    0.044190
# Mouse, H3K9me3, positively enriched (+)                    0.021816
#
#                                           Cell cycle regulation and apoptosis  \
# Human, H3K27ac, negatively enriched (-)                              0.089173
# Human, H3K27ac, positively enriched (+)                              0.998263
# Human, H3K27me3, negatively enriched (-)                             0.966991
# Human, H3K27me3, positively enriched (+)                             0.854441
# Human, H3K4me3, negatively enriched (-)                              0.826744
# Human, H3K4me3, positively enriched (+)                              0.952062
# Human, H3K9ac, negatively enriched (-)                               0.764756
# Human, H3K9ac, positively enriched (+)                               0.971654
# Human, H3K9me3, negatively enriched (-)                              0.203775
# Human, H3K9me3, positively enriched (+)                              0.834310
# Mouse, H3K27ac, negatively enriched (-)                              0.156983
# Mouse, H3K27ac, positively enriched (+)                              0.497153
# Mouse, H3K27me3, negatively enriched (-)                             0.968038
# Mouse, H3K27me3, positively enriched (+)                             0.902649
# Mouse, H3K4me3, negatively enriched (-)                              0.525105
# Mouse, H3K4me3, positively enriched (+)                              0.399148
# Mouse, H3K9ac, negatively enriched (-)                               0.514131
# Mouse, H3K9ac, positively enriched (+)                               0.257112
# Mouse, H3K9me3, negatively enriched (-)                              0.995604
# Mouse, H3K9me3, positively enriched (+)                              0.855871
#
#                                           Chromatin Structure Linked Pathways  \
# Human, H3K27ac, negatively enriched (-)                              0.539746
# Human, H3K27ac, positively enriched (+)                              1.000000
# Human, H3K27me3, negatively enriched (-)                             1.000000
# Human, H3K27me3, positively enriched (+)                             1.000000
# Human, H3K4me3, negatively enriched (-)                              1.000000
# Human, H3K4me3, positively enriched (+)                              1.000000
# Human, H3K9ac, negatively enriched (-)                               1.000000
# Human, H3K9ac, positively enriched (+)                               1.000000
# Human, H3K9me3, negatively enriched (-)                              1.000000
# Human, H3K9me3, positively enriched (+)                              0.354619
# Mouse, H3K27ac, negatively enriched (-)                              1.000000
# Mouse, H3K27ac, positively enriched (+)                              1.000000
# Mouse, H3K27me3, negatively enriched (-)                             1.000000
# Mouse, H3K27me3, positively enriched (+)                             1.000000
# Mouse, H3K4me3, negatively enriched (-)                              1.000000
# Mouse, H3K4me3, positively enriched (+)                              1.000000
# Mouse, H3K9ac, negatively enriched (-)                               1.000000
# Mouse, H3K9ac, positively enriched (+)                               1.000000
# Mouse, H3K9me3, negatively enriched (-)                              1.000000
# Mouse, H3K9me3, positively enriched (+)                              1.000000
#
#                                           Cytoskeleton Organisation and Cell Adhesion Linked Pathways   \
# Human, H3K27ac, negatively enriched (-)                                            1.000000
# Human, H3K27ac, positively enriched (+)                                            0.741372
# Human, H3K27me3, negatively enriched (-)                                           1.000000
# Human, H3K27me3, positively enriched (+)                                           0.977169
# Human, H3K4me3, negatively enriched (-)                                            1.000000
# Human, H3K4me3, positively enriched (+)                                            0.983318
# Human, H3K9ac, negatively enriched (-)                                             0.899741
# Human, H3K9ac, positively enriched (+)                                             0.978046
# Human, H3K9me3, negatively enriched (-)                                            0.910736
# Human, H3K9me3, positively enriched (+)                                            0.167189
# Mouse, H3K27ac, negatively enriched (-)                                            0.775924
# Mouse, H3K27ac, positively enriched (+)                                            1.000000
# Mouse, H3K27me3, negatively enriched (-)                                           0.976256
# Mouse, H3K27me3, positively enriched (+)                                           0.222243
# Mouse, H3K4me3, negatively enriched (-)                                            0.148431
# Mouse, H3K4me3, positively enriched (+)                                            1.000000
# Mouse, H3K9ac, negatively enriched (-)                                             0.143827
# Mouse, H3K9ac, positively enriched (+)                                             1.000000
# Mouse, H3K9me3, negatively enriched (-)                                            0.852447
# Mouse, H3K9me3, positively enriched (+)                                            0.139863
#
#                                           DNA replication, recombination and repair  \
# Human, H3K27ac, negatively enriched (-)                                5.767476e-01
# Human, H3K27ac, positively enriched (+)                                1.000000e+00
# Human, H3K27me3, negatively enriched (-)                               1.000000e+00
# Human, H3K27me3, positively enriched (+)                               5.714523e-08
# Human, H3K4me3, negatively enriched (-)                                2.467930e-01
# Human, H3K4me3, positively enriched (+)                                1.000000e+00
# Human, H3K9ac, negatively enriched (-)                                 5.858523e-01
# Human, H3K9ac, positively enriched (+)                                 1.000000e+00
# Human, H3K9me3, negatively enriched (-)                                1.000000e+00
# Human, H3K9me3, positively enriched (+)                                6.049911e-01
# Mouse, H3K27ac, negatively enriched (-)                                4.617285e-01
# Mouse, H3K27ac, positively enriched (+)                                1.000000e+00
# Mouse, H3K27me3, negatively enriched (-)                               1.000000e+00
# Mouse, H3K27me3, positively enriched (+)                               1.000000e+00
# Mouse, H3K4me3, negatively enriched (-)                                3.106370e-01
# Mouse, H3K4me3, positively enriched (+)                                1.000000e+00
# Mouse, H3K9ac, negatively enriched (-)                                 4.970094e-01
# Mouse, H3K9ac, positively enriched (+)                                 1.000000e+00
# Mouse, H3K9me3, negatively enriched (-)                                7.846082e-01
# Mouse, H3K9me3, positively enriched (+)                                1.000000e+00
#
#                                           Hormone Linked Pathways  \
# Human, H3K27ac, negatively enriched (-)                  1.000000
# Human, H3K27ac, positively enriched (+)                  0.325504
# Human, H3K27me3, negatively enriched (-)                 0.102526
# Human, H3K27me3, positively enriched (+)                 1.000000
# Human, H3K4me3, negatively enriched (-)                  1.000000
# Human, H3K4me3, positively enriched (+)                  0.588870
# Human, H3K9ac, negatively enriched (-)                   1.000000
# Human, H3K9ac, positively enriched (+)                   0.777781
# Human, H3K9me3, negatively enriched (-)                  0.835676
# Human, H3K9me3, positively enriched (+)                  1.000000
# Mouse, H3K27ac, negatively enriched (-)                  0.953097
# Mouse, H3K27ac, positively enriched (+)                  1.000000
# Mouse, H3K27me3, negatively enriched (-)                 1.000000
# Mouse, H3K27me3, positively enriched (+)                 0.830850
# Mouse, H3K4me3, negatively enriched (-)                  0.960680
# Mouse, H3K4me3, positively enriched (+)                  1.000000
# Mouse, H3K9ac, negatively enriched (-)                   0.959506
# Mouse, H3K9ac, positively enriched (+)                   1.000000
# Mouse, H3K9me3, negatively enriched (-)                  0.044197
# Mouse, H3K9me3, positively enriched (+)                  0.327351
#
#                                           Immunity Linked Pathways  \
# Human, H3K27ac, negatively enriched (-)                   0.562063
# Human, H3K27ac, positively enriched (+)                   0.002116
# Human, H3K27me3, negatively enriched (-)                  0.587725
# Human, H3K27me3, positively enriched (+)                  0.893701
# Human, H3K4me3, negatively enriched (-)                   1.000000
# Human, H3K4me3, positively enriched (+)                   0.115611
# Human, H3K9ac, negatively enriched (-)                    0.981192
# Human, H3K9ac, positively enriched (+)                    0.004593
# Human, H3K9me3, negatively enriched (-)                   0.002068
# Human, H3K9me3, positively enriched (+)                   0.952397
# Mouse, H3K27ac, negatively enriched (-)                   0.993245
# Mouse, H3K27ac, positively enriched (+)                   0.969984
# Mouse, H3K27me3, negatively enriched (-)                  0.001595
# Mouse, H3K27me3, positively enriched (+)                  0.600226
# Mouse, H3K4me3, negatively enriched (-)                   0.941841
# Mouse, H3K4me3, positively enriched (+)                   0.955229
# Mouse, H3K9ac, negatively enriched (-)                    0.939203
# Mouse, H3K9ac, positively enriched (+)                    0.828558
# Mouse, H3K9me3, negatively enriched (-)                   0.546068
# Mouse, H3K9me3, positively enriched (+)                   0.691698
#
#                                                  ...          \
# Human, H3K27ac, negatively enriched (-)          ...
# Human, H3K27ac, positively enriched (+)          ...
# Human, H3K27me3, negatively enriched (-)         ...
# Human, H3K27me3, positively enriched (+)         ...
# Human, H3K4me3, negatively enriched (-)          ...
# Human, H3K4me3, positively enriched (+)          ...
# Human, H3K9ac, negatively enriched (-)           ...
# Human, H3K9ac, positively enriched (+)           ...
# Human, H3K9me3, negatively enriched (-)          ...
# Human, H3K9me3, positively enriched (+)          ...
# Mouse, H3K27ac, negatively enriched (-)          ...
# Mouse, H3K27ac, positively enriched (+)          ...
# Mouse, H3K27me3, negatively enriched (-)         ...
# Mouse, H3K27me3, positively enriched (+)         ...
# Mouse, H3K4me3, negatively enriched (-)          ...
# Mouse, H3K4me3, positively enriched (+)          ...
# Mouse, H3K9ac, negatively enriched (-)           ...
# Mouse, H3K9ac, positively enriched (+)           ...
# Mouse, H3K9me3, negatively enriched (-)          ...
# Mouse, H3K9me3, positively enriched (+)          ...
#
#                                           Mitochondria Linked Pathways  \
# Human, H3K27ac, negatively enriched (-)                       1.000000
# Human, H3K27ac, positively enriched (+)                       1.000000
# Human, H3K27me3, negatively enriched (-)                      0.496289
# Human, H3K27me3, positively enriched (+)                      1.000000
# Human, H3K4me3, negatively enriched (-)                       1.000000
# Human, H3K4me3, positively enriched (+)                       1.000000
# Human, H3K9ac, negatively enriched (-)                        1.000000
# Human, H3K9ac, positively enriched (+)                        1.000000
# Human, H3K9me3, negatively enriched (-)                       0.507601
# Human, H3K9me3, positively enriched (+)                       1.000000
# Mouse, H3K27ac, negatively enriched (-)                       1.000000
# Mouse, H3K27ac, positively enriched (+)                       0.119282
# Mouse, H3K27me3, negatively enriched (-)                      1.000000
# Mouse, H3K27me3, positively enriched (+)                      1.000000
# Mouse, H3K4me3, negatively enriched (-)                       1.000000
# Mouse, H3K4me3, positively enriched (+)                       0.097914
# Mouse, H3K9ac, negatively enriched (-)                        0.715790
# Mouse, H3K9ac, positively enriched (+)                        0.101392
# Mouse, H3K9me3, negatively enriched (-)                       1.000000
# Mouse, H3K9me3, positively enriched (+)                       1.000000
#
#                                           Molecular Transport pathways  \
# Human, H3K27ac, negatively enriched (-)                       1.000000
# Human, H3K27ac, positively enriched (+)                       0.844481
# Human, H3K27me3, negatively enriched (-)                      0.018326
# Human, H3K27me3, positively enriched (+)                      0.961508
# Human, H3K4me3, negatively enriched (-)                       1.000000
# Human, H3K4me3, positively enriched (+)                       0.067062
# Human, H3K9ac, negatively enriched (-)                        0.862225
# Human, H3K9ac, positively enriched (+)                        0.236147
# Human, H3K9me3, negatively enriched (-)                       0.875350
# Human, H3K9me3, positively enriched (+)                       0.823176
# Mouse, H3K27ac, negatively enriched (-)                       0.001055
# Mouse, H3K27ac, positively enriched (+)                       1.000000
# Mouse, H3K27me3, negatively enriched (-)                      0.960187
# Mouse, H3K27me3, positively enriched (+)                      1.000000
# Mouse, H3K4me3, negatively enriched (-)                       0.014032
# Mouse, H3K4me3, positively enriched (+)                       1.000000
# Mouse, H3K9ac, negatively enriched (-)                        0.004671
# Mouse, H3K9ac, positively enriched (+)                        1.000000
# Mouse, H3K9me3, negatively enriched (-)                       0.077106
# Mouse, H3K9me3, positively enriched (+)                       0.674087
#
#                                           Nucleic Base Metabolism     Other  \
# Human, H3K27ac, negatively enriched (-)                  0.060329  0.001011
# Human, H3K27ac, positively enriched (+)                  0.012756  0.840660
# Human, H3K27me3, negatively enriched (-)                 1.000000  1.000000
# Human, H3K27me3, positively enriched (+)                 0.035842  0.625892
# Human, H3K4me3, negatively enriched (-)                  0.041776  0.002161
# Human, H3K4me3, positively enriched (+)                  0.265831  0.969633
# Human, H3K9ac, negatively enriched (-)                   0.017789  0.004542
# Human, H3K9ac, positively enriched (+)                   0.228788  0.836542
# Human, H3K9me3, negatively enriched (-)                  0.204401  1.000000
# Human, H3K9me3, positively enriched (+)                  0.414715  0.604991
# Mouse, H3K27ac, negatively enriched (-)                  0.484965  0.461728
# Mouse, H3K27ac, positively enriched (+)                  1.000000  0.823138
# Mouse, H3K27me3, negatively enriched (-)                 0.909002  0.828019
# Mouse, H3K27me3, positively enriched (+)                 0.004938  0.868596
# Mouse, H3K4me3, negatively enriched (-)                  0.298446  0.713342
# Mouse, H3K4me3, positively enriched (+)                  0.684020  1.000000
# Mouse, H3K9ac, negatively enriched (-)                   0.515614  0.707649
# Mouse, H3K9ac, positively enriched (+)                   0.691729  1.000000
# Mouse, H3K9me3, negatively enriched (-)                  0.006743  0.944568
# Mouse, H3K9me3, positively enriched (+)                  0.821328  0.899167
#
#                                           Perception and Neurotransmission  \
# Human, H3K27ac, negatively enriched (-)                           1.000000
# Human, H3K27ac, positively enriched (+)                           0.737934
# Human, H3K27me3, negatively enriched (-)                          0.474399
# Human, H3K27me3, positively enriched (+)                          1.000000
# Human, H3K4me3, negatively enriched (-)                           1.000000
# Human, H3K4me3, positively enriched (+)                           0.002182
# Human, H3K9ac, negatively enriched (-)                            1.000000
# Human, H3K9ac, positively enriched (+)                            0.016672
# Human, H3K9me3, negatively enriched (-)                           1.000000
# Human, H3K9me3, positively enriched (+)                           1.000000
# Mouse, H3K27ac, negatively enriched (-)                           1.000000
# Mouse, H3K27ac, positively enriched (+)                           1.000000
# Mouse, H3K27me3, negatively enriched (-)                          1.000000
# Mouse, H3K27me3, positively enriched (+)                          1.000000
# Mouse, H3K4me3, negatively enriched (-)                           1.000000
# Mouse, H3K4me3, positively enriched (+)                           1.000000
# Mouse, H3K9ac, negatively enriched (-)                            1.000000
# Mouse, H3K9ac, positively enriched (+)                            1.000000
# Mouse, H3K9me3, negatively enriched (-)                           0.671334
# Mouse, H3K9me3, positively enriched (+)                           0.840000
#
#                                           RNA synthesis, processing and degradation  \
# Human, H3K27ac, negatively enriched (-)                                    0.319614
# Human, H3K27ac, positively enriched (+)                                    1.000000
# Human, H3K27me3, negatively enriched (-)                                   1.000000
# Human, H3K27me3, positively enriched (+)                                   0.853926
# Human, H3K4me3, negatively enriched (-)                                    0.020017
# Human, H3K4me3, positively enriched (+)                                    1.000000
# Human, H3K9ac, negatively enriched (-)                                     0.114166
# Human, H3K9ac, positively enriched (+)                                     1.000000
# Human, H3K9me3, negatively enriched (-)                                    1.000000
# Human, H3K9me3, positively enriched (+)                                    0.116303
# Mouse, H3K27ac, negatively enriched (-)                                    1.000000
# Mouse, H3K27ac, positively enriched (+)                                    1.000000
# Mouse, H3K27me3, negatively enriched (-)                                   1.000000
# Mouse, H3K27me3, positively enriched (+)                                   1.000000
# Mouse, H3K4me3, negatively enriched (-)                                    0.373705
# Mouse, H3K4me3, positively enriched (+)                                    1.000000
# Mouse, H3K9ac, negatively enriched (-)                                     0.887347
# Mouse, H3K9ac, positively enriched (+)                                     1.000000
# Mouse, H3K9me3, negatively enriched (-)                                    1.000000
# Mouse, H3K9me3, positively enriched (+)                                    1.000000
#
#                                           Signaling  \
# Human, H3K27ac, negatively enriched (-)    0.984301
# Human, H3K27ac, positively enriched (+)    1.000000
# Human, H3K27me3, negatively enriched (-)   0.512876
# Human, H3K27me3, positively enriched (+)   0.999087
# Human, H3K4me3, negatively enriched (-)    0.999965
# Human, H3K4me3, positively enriched (+)    1.000000
# Human, H3K9ac, negatively enriched (-)     0.996597
# Human, H3K9ac, positively enriched (+)     1.000000
# Human, H3K9me3, negatively enriched (-)    0.995954
# Human, H3K9me3, positively enriched (+)    0.938690
# Mouse, H3K27ac, negatively enriched (-)    0.963178
# Mouse, H3K27ac, positively enriched (+)    0.900091
# Mouse, H3K27me3, negatively enriched (-)   0.993979
# Mouse, H3K27me3, positively enriched (+)   0.982762
# Mouse, H3K4me3, negatively enriched (-)    0.961979
# Mouse, H3K4me3, positively enriched (+)    0.996009
# Mouse, H3K9ac, negatively enriched (-)     0.869422
# Mouse, H3K9ac, positively enriched (+)     0.996774
# Mouse, H3K9me3, negatively enriched (-)    0.999295
# Mouse, H3K9me3, positively enriched (+)    0.732119
#
#                                           Sulfur Metabolism and Linked Redox Reactions  \
# Human, H3K27ac, negatively enriched (-)                                       1.000000
# Human, H3K27ac, positively enriched (+)                                       0.190137
# Human, H3K27me3, negatively enriched (-)                                      1.000000
# Human, H3K27me3, positively enriched (+)                                      0.184360
# Human, H3K4me3, negatively enriched (-)                                       1.000000
# Human, H3K4me3, positively enriched (+)                                       0.207623
# Human, H3K9ac, negatively enriched (-)                                        1.000000
# Human, H3K9ac, positively enriched (+)                                        0.187245
# Human, H3K9me3, negatively enriched (-)                                       1.000000
# Human, H3K9me3, positively enriched (+)                                       0.175752
# Mouse, H3K27ac, negatively enriched (-)                                       1.000000
# Mouse, H3K27ac, positively enriched (+)                                       1.000000
# Mouse, H3K27me3, negatively enriched (-)                                      0.041936
# Mouse, H3K27me3, positively enriched (+)                                      1.000000
# Mouse, H3K4me3, negatively enriched (-)                                       1.000000
# Mouse, H3K4me3, positively enriched (+)                                       0.314191
# Mouse, H3K9ac, negatively enriched (-)                                        1.000000
# Mouse, H3K9ac, positively enriched (+)                                        0.319714
# Mouse, H3K9me3, negatively enriched (-)                                       0.508786
# Mouse, H3K9me3, positively enriched (+)                                       1.000000
#
#                                           Translation and protein maturation  \
# Human, H3K27ac, negatively enriched (-)                             0.098382
# Human, H3K27ac, positively enriched (+)                             1.000000
# Human, H3K27me3, negatively enriched (-)                            1.000000
# Human, H3K27me3, positively enriched (+)                            0.110268
# Human, H3K4me3, negatively enriched (-)                             0.000497
# Human, H3K4me3, positively enriched (+)                             1.000000
# Human, H3K9ac, negatively enriched (-)                              0.000155
# Human, H3K9ac, positively enriched (+)                              1.000000
# Human, H3K9me3, negatively enriched (-)                             1.000000
# Human, H3K9me3, positively enriched (+)                             1.000000
# Mouse, H3K27ac, negatively enriched (-)                             0.048188
# Mouse, H3K27ac, positively enriched (+)                             1.000000
# Mouse, H3K27me3, negatively enriched (-)                            1.000000
# Mouse, H3K27me3, positively enriched (+)                            1.000000
# Mouse, H3K4me3, negatively enriched (-)                             0.155544
# Mouse, H3K4me3, positively enriched (+)                             1.000000
# Mouse, H3K9ac, negatively enriched (-)                              0.339442
# Mouse, H3K9ac, positively enriched (+)                              1.000000
# Mouse, H3K9me3, negatively enriched (-)                             1.000000
# Mouse, H3K9me3, positively enriched (+)                             1.000000
#
#                                           Vitamin Metabolism
# Human, H3K27ac, negatively enriched (-)             1.000000
# Human, H3K27ac, positively enriched (+)             0.389585
# Human, H3K27me3, negatively enriched (-)            1.000000
# Human, H3K27me3, positively enriched (+)            0.145180
# Human, H3K4me3, negatively enriched (-)             1.000000
# Human, H3K4me3, positively enriched (+)             0.170779
# Human, H3K9ac, negatively enriched (-)              1.000000
# Human, H3K9ac, positively enriched (+)              0.738754
# Human, H3K9me3, negatively enriched (-)             0.572246
# Human, H3K9me3, positively enriched (+)             0.365553
# Mouse, H3K27ac, negatively enriched (-)             1.000000
# Mouse, H3K27ac, positively enriched (+)             1.000000
# Mouse, H3K27me3, negatively enriched (-)            0.731457
# Mouse, H3K27me3, positively enriched (+)            1.000000
# Mouse, H3K4me3, negatively enriched (-)             0.781677
# Mouse, H3K4me3, positively enriched (+)             1.000000
# Mouse, H3K9ac, negatively enriched (-)              0.778636
# Mouse, H3K9ac, positively enriched (+)              1.000000
# Mouse, H3K9me3, negatively enriched (-)             0.696086
# Mouse, H3K9me3, positively enriched (+)             1.000000
#
# [20 rows x 22 columns]

# %%
TAU = pd.DataFrame(ksi)

# %%
def get_highlighter_min(color, point):
    def highlight_min(s):
        '''
        highlight the minimums in a Series.
        '''
        is_max = s <= point
        return [f'background-color: {color}' if v else '' for v in is_max]
    return highlight_min

# %%
data_round = np.round(TAU, 3)
cm = sns.light_palette("green", as_cmap=True, reverse=True)

s = data_round.style.apply(get_highlighter_min("green", 0.05), subset=([i for i in TAU.index if "+" in i], TAU.columns))
cm = sns.light_palette("red", as_cmap=True, reverse=True)

s.apply(get_highlighter_min("red", 0.05), subset=([i for i in TAU.index if "-" in i], TAU.columns))
s
# Out:
# <style  type="text/css" >
#     #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col15 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow1_col0 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow1_col3 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow1_col9 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow1_col11 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow1_col14 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow2_col13 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow3_col7 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow3_col14 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow4_col14 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow4_col15 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow4_col17 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow4_col20 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow5_col0 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow5_col3 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow5_col11 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow5_col16 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow6_col14 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow6_col15 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow6_col20 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow7_col0 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow7_col9 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow7_col11 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow7_col16 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow8_col9 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow10_col13 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow10_col20 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow11_col3 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow12_col0 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow12_col9 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow12_col11 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow12_col19 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow13_col0 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow13_col3 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow13_col14 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow14_col13 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow15_col3 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow15_col11 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow16_col13 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow17_col11 {
#             background-color:  green;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow18_col3 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow18_col8 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow18_col14 {
#             background-color:  red;
#         }    #T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow19_col3 {
#             background-color:  green;
#         }</style>
# <table id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7db" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Aminoacids and Polyamines Metabolism</th>
#         <th class="col_heading level0 col1" >Cancer and Tumorigenesis Linked Pathways</th>
#         <th class="col_heading level0 col2" >Carbohydrates Metabolism</th>
#         <th class="col_heading level0 col3" >Catabolism of Xenobiotics</th>
#         <th class="col_heading level0 col4" >Cell cycle regulation and apoptosis</th>
#         <th class="col_heading level0 col5" >Chromatin Structure Linked Pathways</th>
#         <th class="col_heading level0 col6" >Cytoskeleton Organisation and Cell Adhesion Linked Pathways </th>
#         <th class="col_heading level0 col7" >DNA replication, recombination and repair</th>
#         <th class="col_heading level0 col8" >Hormone Linked Pathways</th>
#         <th class="col_heading level0 col9" >Immunity Linked Pathways</th>
#         <th class="col_heading level0 col10" >Invasive Disease</th>
#         <th class="col_heading level0 col11" >Lipids Metabolism</th>
#         <th class="col_heading level0 col12" >Mitochondria Linked Pathways</th>
#         <th class="col_heading level0 col13" >Molecular Transport pathways</th>
#         <th class="col_heading level0 col14" >Nucleic Base Metabolism</th>
#         <th class="col_heading level0 col15" >Other</th>
#         <th class="col_heading level0 col16" >Perception and Neurotransmission</th>
#         <th class="col_heading level0 col17" >RNA synthesis, processing and degradation</th>
#         <th class="col_heading level0 col18" >Signaling</th>
#         <th class="col_heading level0 col19" >Sulfur Metabolism and Linked Redox Reactions</th>
#         <th class="col_heading level0 col20" >Translation and protein maturation</th>
#         <th class="col_heading level0 col21" >Vitamin Metabolism</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dblevel0_row0" class="row_heading level0 row0" >Human, H3K27ac, negatively enriched (-)</th>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col0" class="data row0 col0" >1</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col1" class="data row0 col1" >1</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col2" class="data row0 col2" >1</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col3" class="data row0 col3" >1</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col4" class="data row0 col4" >0.089</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col5" class="data row0 col5" >0.54</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col6" class="data row0 col6" >1</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col7" class="data row0 col7" >0.577</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col8" class="data row0 col8" >1</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col9" class="data row0 col9" >0.562</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col10" class="data row0 col10" >1</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col11" class="data row0 col11" >0.934</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col12" class="data row0 col12" >1</td>
#         <td id="T_fcb7f8f4_265b_11e9_abd8_0c84dc02d7dbrow0_col13" class="data row0 col13" >1</td>
